# %%
import pandas as pd
#import matplotlib as

# %%
man =pd.Series([27,5,5], index=['victoires','defaites','nuls'] )
man
# Out:
# victoires    27
# defaites      5
# nuls          5
# dtype: int64

# %%
#create dataframe
df_man = pd.DataFrame(man)
df_man
# Out:
#             0
# victoires  27
# defaites    5
# nuls        5

# %%
labels=man.index

# %%
colors = sns.color_palette('bright')
plt.pie(man, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = [35, 21, 29, 39, 11]
labels = ['slice 1', 'slice 2', 'slice 3', 'slice 4', 'slice 5']
colors = sns.color_palette('bright')
plt.pie(data, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.show()

# %%
explode = [0.3,0.02,0.02,0.02,0.02]
labels = ['slice 1', 'slice 2', 'slice 3', 'slice 4', 'slice 5']
colors = sns.color_palette('bright')
plt.pie(data, labels=labels,colors = colors, autopct = '%0.0f%%', explode = explode)
plt.show()

# %%
# Données
labels = df_chelsea_resultat['Result']
data = df_chelsea_resultat['nbr_matchs']

explode = [0.1,0.02,0.02]
colors = sns.color_palette('bright')
plt.pie(data, labels=labels,colors = colors, autopct = '%0.0f%%', explode = explode)

plt.rcParams['figure.figsize']=[7,7] # Dimension du graphique
plt.title('Répartition du nombres de victoires, defaite et defaite de chelsea  ')
plt.legend(title ="Proportion des résultats par nbr de matchs")
plt.show()

# %%
df_man_city = pd.read_excel('./Man_city_All.xlsx')
df_man_city.head()
# Out:
#    Unnamed: 0  HomeTeam  Date_maths  FTHG  AwayTeam  FTAG  nb_toatl
# 0           0  Man City           1     8  Man City     7        15
# 1           1  Man City           2     9  Man City     4        13
# 2           2  Man City           5     7  Man City     6        13
# 3           3  Man City           7     0  Man City     4         4
# 4           4  Man City           8     2         0     0         2

# %%
df_man_city.rename(columns={'nb_toatl' : 'nbr_total'},inplace=True)
df_man_city.rename(columns={'Date_maths' : 'Date_match'},inplace=True)

# %%
nbr_but_mois=df_man_city.sort_values(by='Date_match', ascending=True)
nbr_but_mois.head()
# Out:
#     Unnamed: 0  HomeTeam  Date_match  FTHG  AwayTeam  FTAG  nbr_total
# 0            0  Man City           1     8  Man City     7         15
# 1            1  Man City           2     9  Man City     4         13
# 9            9         0           3     0  Man City    11         11
# 10          10         0           4     0  Man City     2          2
# 2            2  Man City           5     7  Man City     6         13

# %%
type(nbr_but_mois)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
nbr_but_tab = np.array(nbr_but_mois)
nbr_but_tab
# Out:
# array([[0, 'Man City', 1, 8, 'Man City', 7, 15],
#        [1, 'Man City', 2, 9, 'Man City', 4, 13],
#        [9, 0, 3, 0, 'Man City', 11, 11],
#        [10, 0, 4, 0, 'Man City', 2, 2],
#        [2, 'Man City', 5, 7, 'Man City', 6, 13],
#        [3, 'Man City', 7, 0, 'Man City', 4, 4],
#        [4, 'Man City', 8, 2, 0, 0, 2],
#        [5, 'Man City', 9, 2, 'Man City', 3, 5],
#        [6, 'Man City', 10, 7, 'Man City', 2, 9],
#        [7, 'Man City', 11, 5, 'Man City', 0, 5],
#        [8, 'Man City', 12, 3, 'Man City', 1, 4]], dtype=object)

# %%
# Afficher le nom de chaque type de carrosserie
label=nbr_but_tab['AwayTeam'].value_counts().index
labelw²
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7760/1333740483.py in <module>
#       1 # Afficher le nom de chaque type de carrosserie
# ----> 2 label=nbr_but_tab['FTHG'].value_counts().index
#       3 label
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df_man_city = df_PL_2021_2021_matchs[(df_PL_2021_2021_matchs['HomeTeam']=='Man City') | (df_PL_2021_2021_matchs['AwayTeam']=='Man City')] 
df_man_city
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14972/1180222039.py in <module>
# ----> 1 df_man_city = df_PL_2021_2021_matchs[(df_PL_2021_2021_matchs['HomeTeam']=='Man City') | (df_PL_2021_2021_matchs['AwayTeam']=='Man City')]
#       2 df_man_city
#
# NameError: name 'df_PL_2021_2021_matchs' is not defined
